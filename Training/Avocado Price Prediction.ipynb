# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\venka\OneDrive\Desktop\Sravya\Smart Bridge\avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df = df.drop(['Unnamed: 0'],axis = 1)

# %%
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

df = df.drop('Date', axis=1)

# %%
df.drop('Total Bags', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Small Bags',
#        'Large Bags', 'XLarge Bags', 'type', 'year', 'region', 'Month', 'Day'],
#       dtype='object')

# %%
df = df.rename(columns={'4046': 'small/medium Avocados', '4225': 'large Avocados', '4770': 'extra_large Avocados'})
df
# Out:
#        AveragePrice  Total Volume  small/medium Avocados  large Avocados  \
# 0              1.33      64236.62                1036.74        54454.85
# 1              1.35      54876.98                 674.28        44638.81
# 2              0.93     118220.22                 794.70       109149.67
# 3              1.08      78992.15                1132.00        71976.41
# 4              1.28      51039.60                 941.48        43838.39
# ...             ...           ...                    ...             ...
# 18244          1.63      17074.83                2046.96         1529.20
# 18245          1.71      13888.04                1191.70         3431.50
# 18246          1.87      13766.76                1191.92         2452.79
# 18247          1.93      16205.22                1527.63         2981.04
# 18248          1.62      17489.58                2894.77         2356.13
#
#        extra_large Avocados  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
df.isna().sum()
# Out:
# AveragePrice             0
# Total Volume             0
# small/medium Avocados    0
# large Avocados           0
# extra_large Avocados     0
# Small Bags               0
# Large Bags               0
# XLarge Bags              0
# type                     0
# year                     0
# region                   0
# Month                    0
# Day                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
df['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
df['XLarge Bags'].unique()
# Out:
# array([  0.  ,  33.33, 104.17, ..., 228.27,  12.12,  24.18])

# %%
df
# Out:
#        AveragePrice  Total Volume  small/medium Avocados  large Avocados  \
# 0              1.33      64236.62                1036.74        54454.85
# 1              1.35      54876.98                 674.28        44638.81
# 2              0.93     118220.22                 794.70       109149.67
# 3              1.08      78992.15                1132.00        71976.41
# 4              1.28      51039.60                 941.48        43838.39
# ...             ...           ...                    ...             ...
# 18244          1.63      17074.83                2046.96         1529.20
# 18245          1.71      13888.04                1191.70         3431.50
# 18246          1.87      13766.76                1191.92         2452.79
# 18247          1.93      16205.22                1527.63         2981.04
# 18248          1.62      17489.58                2894.77         2356.13
#
#        extra_large Avocados  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
df['region'].nunique()
# Out:
# 54

# %%
sns.boxplot(data = df, x="type", y = df["AveragePrice"]);

# %%
sns.countplot(data=df,x='type')
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
sns.barplot(data=df,x=df.year,y=df["Total Volume"])
plt.show()

# %%
df.drop('Total Volume', axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'type' and 'region' are the columns to be encoded
label_encoder = LabelEncoder()

df['type_encoded'] = label_encoder.fit_transform(df['type'])
df['region_encoded'] = label_encoder.fit_transform(df['region'])

df = df.drop(['type', 'region'], axis=1)

# %%
df
# Out:
#        AveragePrice  small/medium Avocados  large Avocados  \
# 0              1.33                1036.74        54454.85
# 1              1.35                 674.28        44638.81
# 2              0.93                 794.70       109149.67
# 3              1.08                1132.00        71976.41
# 4              1.28                 941.48        43838.39
# ...             ...                    ...             ...
# 18244          1.63                2046.96         1529.20
# 18245          1.71                1191.70         3431.50
# 18246          1.87                1191.92         2452.79
# 18247          1.93                1527.63         2981.04
# 18248          1.62                2894.77         2356.13
#
#        extra_large Avocados  Small Bags  Large Bags  XLarge Bags  year  Month  \
# 0                     48.16     8603.62       93.25          0.0  2015     12
# 1                     58.33     9408.07       97.49          0.0  2015     12
# ...

# %%
df['region_encoded'].value_counts()
# Out:
# 0     338
# 40    338
# 29    338
# 30    338
# 31    338
# 32    338
# 33    338
# 34    338
# 35    338
# 36    338
# 37    338
# 38    338
# 39    338
# 41    338
# 1     338
# 42    338
# 43    338
# 44    338
# 45    338
# 46    338
# 47    338
# 48    338
# 49    338
# 50    338
# 51    338
# 52    338
# 28    338
# 27    338
# 26    338
# 25    338
# 2     338
# 3     338
# 4     338
# 5     338
# 6     338
# 7     338
# 8     338
# 9     338
# 10    338
# 11    338
# 12    338
# 13    338
# 14    338
# 15    338
# 16    338
# 17    338
# 18    338
# 19    338
# 20    338
# 21    338
# 22    338
# 23    338
# 24    338
# 53    335
# Name: region_encoded, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['year'])
plt.title('Boxplot for Year wise Price')
plt.ylabel('Year')
plt.show()

# %% [markdown]
# # Splitting

# %%
x = df.drop('AveragePrice',axis=1)
y=df['AveragePrice']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state = 42)

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.fit_transform(x_test)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
LR = LinearRegression()
LR.fit(x_train, y_train)

y_pred_test_linear = LR.predict(x_test)
linear_r2_test = r2_score(y_test, y_pred_test_linear)
print("Linear Regression Test R-squared:", linear_r2_test)
training_r2_linear = LR.score(x_train, y_train)
print("Linear Regression Training R-squared:", training_r2_linear)
# Out:
# Linear Regression Test R-squared: 0.42690910531283444
# Linear Regression Training R-squared: 0.4439787087195314

# %%
cv_scores_linear_train = cross_val_score(LR, x_train, y_train, cv=5, scoring='r2')

print("Cross-Validation R-squared scores on Training set:", cv_scores_linear_train)
print("Cross-Validation R-squared on Training set:", np.mean(cv_scores_linear_train))
# Out:
# Cross-Validation R-squared scores on Training set: [0.45780043 0.46795213 0.43859717 0.42131405 0.43010272]
# Cross-Validation R-squared on Training set: 0.4431533013718755

# %%
cv_scores_linear_test = cross_val_score(LR, x_test, y_test, cv=5, scoring='r2')

print("Cross-Validation R-squared scores on Test set:", cv_scores_linear_test)
print("Cross-Validation R-squared on Test set:", np.mean(cv_scores_linear_test))
# Out:
# Cross-Validation R-squared scores on Test set: [0.42567643 0.42561416 0.43315718 0.4501248  0.38922845]
# Cross-Validation R-squared on Test set: 0.4247602030198091

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
DTR = DecisionTreeRegressor(criterion='poisson', max_depth=5, random_state=7)
DTR.fit(x_train, y_train)
y_pred_test_dtr = DTR.predict(x_test)

dtr_r2_test = r2_score(y_test, y_pred_test_dtr)
print("Decision Tree Test R-squared:", dtr_r2_test)
training_r2_dtr = DTR.score(x_train, y_train)
print("Decision Tree Training R-squared:", training_r2_dtr)
# Out:
# Decision Tree Test R-squared: 0.3927363693956496
# Decision Tree Training R-squared: 0.6029396830709894

# %%
cv_scores_dtr_train = cross_val_score(DTR, x_train, y_train, cv=5, scoring='r2')

print("Cross-Validation R-squared scores on Training set:", cv_scores_dtr_train)
print("Cross-Validation R-squared on Training set:", np.mean(cv_scores_dtr_train))
# Out:
# Cross-Validation R-squared scores on Training set: [0.6014854  0.60344881 0.59855061 0.56351575 0.57947033]
# Cross-Validation R-squared on Training set: 0.5892941818429305

# %%
cv_scores_dtr_test = cross_val_score(DTR, x_test, y_test, cv=5, scoring='r2')

print("Cross-Validation R-squared scores on Test set:", cv_scores_dtr_test)
print("Cross-Validation R-squared on Test set:", np.mean(cv_scores_dtr_test))
# Out:
# Cross-Validation R-squared scores on Test set: [0.58396099 0.52432008 0.56881968 0.55511344 0.56434343]
# Cross-Validation R-squared on Test set: 0.5593115266109175

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor(n_estimators=100, max_depth=5, random_state=7)
RF.fit(x_train, y_train)
y_pred_test_rf = RF.predict(x_test)

rf_r2_test = r2_score(y_test, y_pred_test_rf)
print("Random Forest Test R-squared:", rf_r2_test)
training_r2_rf = RF.score(x_train, y_train)
print("Random Forest Training R-squared:", training_r2_rf)
# Out:
# Random Forest Test R-squared: 0.47929676317921266
# Random Forest Training R-squared: 0.6375219771197538

# %%
cv_scores_rf_train = cross_val_score(RF, x_train, y_train, cv=5, scoring='r2')

print("\nRandom Forest Cross-Validation R-squared scores on Training set:", cv_scores_rf_train)
print("Average Random Forest Cross-Validation R-squared on Training set:", np.mean(cv_scores_rf_train))
# Out:
# Random Forest Cross-Validation R-squared scores on Training set: [0.62897871 0.64285987 0.63823422 0.60945185 0.61045458]
# Average Random Forest Cross-Validation R-squared on Training set: 0.6259958446163838

# %%
cv_scores_rf_test = cross_val_score(RF, x_test, y_test, cv=5, scoring='r2')

print("\nRandom Forest Cross-Validation R-squared scores on Test set:", cv_scores_rf_test)
print("Average Random Forest Cross-Validation R-squared on Test set:", np.mean(cv_scores_rf_test))
# Out:
# Random Forest Cross-Validation R-squared scores on Test set: [0.62966528 0.60507816 0.62482342 0.59960339 0.61381742]
# Average Random Forest Cross-Validation R-squared on Test set: 0.614597534522423

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
regressor = xgb.XGBRegressor(n_estimators=1000, learning_rate=0.1, max_depth=3, objective='reg:squarederror', random_state=7)
regressor.fit(x_train, y_train)
y_pred_test = regressor.predict(x_test)

xgb_r2_test = r2_score(y_test, y_pred_test)
print("XGBoost Test R-squared:", xgb_r2_test)
training_r2 = regressor.score(x_train, y_train)
print("XGBoost Training R-squared:", training_r2)
# Out:
# XGBoost Test R-squared: -0.021609202994443466
# XGBoost Training R-squared: 0.906104540480631

# %%
cv_scores_xgb_train = cross_val_score(regressor, x_train, y_train, cv=3, scoring='r2')

print("XGBoost Cross-Validation R-squared scores on Training set:", cv_scores_xgb_train)
print("Average XGBoost Cross-Validation R-squared on Training set:", np.mean(cv_scores_xgb_train))
# Out:
# XGBoost Cross-Validation R-squared scores on Training set: [0.86097082 0.86702126 0.86019689]
# Average XGBoost Cross-Validation R-squared on Training set: 0.8627296548613259

# %%
cv_scores_xgb_test = cross_val_score(regressor, x_test, y_test, cv=3, scoring='r2')

print("\nXGBoost Cross-Validation R-squared scores on Test set:", cv_scores_xgb_test)
print("Average XGBoost Cross-Validation R-squared on Test set:", np.mean(cv_scores_xgb_test))
# Out:
# XGBoost Cross-Validation R-squared scores on Test set: [0.84644997 0.83821725 0.83299487]
# Average XGBoost Cross-Validation R-squared on Test set: 0.839220697245414

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
KNN = KNeighborsRegressor(n_neighbors=15)
KNN.fit(x_train, y_train)
y_pred_test_knn = KNN.predict(x_test)

knn_r2_test = r2_score(y_test, y_pred_test_knn)
print("KNN Test R-squared:", knn_r2_test)
training_r2_knn = KNN.score(x_train, y_train)
print("KNN Training R-squared:", training_r2_knn)
# Out:
# KNN Test R-squared: 0.552442392458851
# KNN Training R-squared: 0.6133924077774193

# %%
accuracy_df = pd.DataFrame({'model':['Linear Regression','Decision Tree Regressor','Random Forest Regressor','XGBoost','KNN'],
                           'R2_score' : [np.mean(cv_scores_linear_test),np.mean(cv_scores_dtr_test),np.mean(cv_scores_rf_test),np.mean(cv_scores_xgb_test),knn_r2_test]})
accuracy_df
# Out:
#                      model  R2_score
# 0        Linear Regression  0.424760
# 1  Decision Tree Regressor  0.559312
# 2  Random Forest Regressor  0.614598
# 3                  XGBoost  0.839221
# 4                      KNN  0.552442

# %%
model = ['Linear Regression','Decision Tree Regressor','Random Forest Regressor','XGBoost','KNN']
R2_score = [np.mean(cv_scores_linear_test),np.mean(cv_scores_dtr_test),np.mean(cv_scores_rf_test),np.mean(cv_scores_xgb_test),knn_r2_test]
plt.figure(figsize=(12,8))
sns.barplot(x=model,y=R2_score,color = 'Purple')
plt.show()

# %%
df
# Out:
#        AveragePrice  small/medium Avocados  large Avocados  \
# 0              1.33                1036.74        54454.85
# 1              1.35                 674.28        44638.81
# 2              0.93                 794.70       109149.67
# 3              1.08                1132.00        71976.41
# 4              1.28                 941.48        43838.39
# ...             ...                    ...             ...
# 18244          1.63                2046.96         1529.20
# 18245          1.71                1191.70         3431.50
# 18246          1.87                1191.92         2452.79
# 18247          1.93                1527.63         2981.04
# 18248          1.62                2894.77         2356.13
#
#        extra_large Avocados  Small Bags  Large Bags  XLarge Bags  year  Month  \
# 0                     48.16     8603.62       93.25          0.0  2015     12
# 1                     58.33     9408.07       97.49          0.0  2015     12
# ...

# %%
print(regressor.predict([[5,0,3,5,0,0,2,4,6,4,18]]))
# Out:
# [1.2690855]

# %%
import pickle 
pickle.dump(regressor,open("xgb_avocado.pkl","wb"))
